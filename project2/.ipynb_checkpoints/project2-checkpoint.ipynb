# %%
import sqlite3
import pandas
import numpy as np

## Part 1
## Problem 1
sqlite_file = 'lahman2014.sqlite'
conn = sqlite3.connect(sqlite_file)

salary_query = "SELECT teamID, yearID, sum(salary)/1000 as total_payroll_by_thousand, sum(salary)/count(salary) as payroll_mean FROM Salaries GROUP BY teamID, yearID"

team_salaries = pandas.read_sql(salary_query, conn)

team_query = "SELECT (W*100.0/G) as winning_percentage, * FROM Teams GROUP BY teamID, yearID"

mean_query = "SELECT yearID, sum(salary)/count(salary) as salary_mean FROM Salaries GROUP BY yearID"

team_table = pandas.read_sql(team_query, conn)
mean_table = pandas.read_sql(mean_query,conn)
#team_salaries
result = pandas.merge(team_salaries, team_table, how='outer', on=['teamID','yearID'])
result = pandas.merge(result, mean_table, how='outer', on=['yearID'])
#team_table
result
# Out:
#      teamID  yearID  total_payroll_by_thousand   payroll_mean  \
# 0       ATL    1985                  14807.000  673045.454545
# 1       BAL    1985                  11560.712  525486.909091
# 2       BOS    1985                  10897.560  435902.400000
# 3       CAL    1985                  14427.894  515281.928571
# 4       CHA    1985                   9846.178  468865.619048
# 5       CHN    1985                  12702.917  577405.318182
# 6       CIN    1985                   8359.917  379996.227273
# 7       CLE    1985                   6551.666  327583.300000
# 8       DET    1985                  10348.143  517407.150000
# 9       HOU    1985                   9993.051  499652.550000
# 10      KCA    1985                   9321.179  423689.954545
# 11      LAN    1985                  10967.917  476865.956522
# 12      MIN    1985                   5764.821  303411.631579
# 13      ML4    1985                  11284.107  593900.368421
# 14      MON    1985                   9470.166  473508.300000
# 15      NYA    1985                  14238.204  711910.200000
# 16      NYN    1985                  10834.762  515941.047619
# 17      OAK    1985                   9058.606  431362.190476
# 18      PHI    1985                  10124.966  532892.947368
# 19      PIT    1985                   9227.500  485657.894737
# 20      SDN    1985                  11036.583  501662.863636
# 21      SEA    1985                   4613.000  256277.777778
# 22      SFN    1985                   8221.714  411085.700000
# 23      SLN    1985                  11817.083  472683.320000
# 24      TEX    1985                   7676.500  383825.000000
# 25      TOR    1985                   8812.550  440627.500000
# 26      ATL    1986                  17102.786  589751.241379
# 27      BAL    1986                  13001.258  448319.241379
# 28      BOS    1986                  14402.239  496628.931034
# 29      CAL    1986                  14427.258  497491.655172
# ...     ...     ...                        ...            ...
# 2747    SLN    1900                        NaN            NaN
# 2748    BS1    1871                        NaN            NaN
# 2749    CH1    1871                        NaN            NaN
# 2750    CL1    1871                        NaN            NaN
# 2751    FW1    1871                        NaN            NaN
# 2752    NY2    1871                        NaN            NaN
# 2753    PH1    1871                        NaN            NaN
# 2754    RC1    1871                        NaN            NaN
# 2755    TRO    1871                        NaN            NaN
# 2756    WS3    1871                        NaN            NaN
# 2757    BSN    1876                        NaN            NaN
# 2758    CHN    1876                        NaN            NaN
# 2759    CN1    1876                        NaN            NaN
# 2760    HAR    1876                        NaN            NaN
# 2761    LS1    1876                        NaN            NaN
# 2762    NY3    1876                        NaN            NaN
# 2763    PHN    1876                        NaN            NaN
# 2764    SL3    1876                        NaN            NaN
# 2765    BSN    1877                        NaN            NaN
# 2766    CHN    1877                        NaN            NaN
# 2767    CN1    1877                        NaN            NaN
# 2768    HAR    1877                        NaN            NaN
# 2769    LS1    1877                        NaN            NaN
# 2770    SL3    1877                        NaN            NaN
# 2771    BSN    1878                        NaN            NaN
# 2772    CHN    1878                        NaN            NaN
# 2773    CN1    1878                        NaN            NaN
# 2774    IN1    1878                        NaN            NaN
# 2775    ML2    1878                        NaN            NaN
# 2776    PRO    1878                        NaN            NaN
#
#       winning_percentage lgID franchID divID  Rank      G      ...        \
# 0              40.740741   NL      ATL     W   5.0  162.0      ...
# 1              51.552795   AL      BAL     E   4.0  161.0      ...
# 2              49.693252   AL      BOS     E   5.0  163.0      ...
# 3              55.555556   AL      ANA     W   2.0  162.0      ...
# 4              52.147239   AL      CHW     W   3.0  163.0      ...
# 5              47.530864   NL      CHC     E   4.0  162.0      ...
# 6              54.938272   NL      CIN     W   2.0  162.0      ...
# 7              37.037037   AL      CLE     E   7.0  162.0      ...
# 8              52.173913   AL      DET     E   3.0  161.0      ...
# 9              51.234568   NL      HOU     W   3.0  162.0      ...
# 10             56.172840   AL      KCR     W   1.0  162.0      ...
# 11             58.641975   NL      LAD     W   1.0  162.0      ...
# 12             47.530864   AL      MIN     W   4.0  162.0      ...
# 13             44.099379   AL      MIL     E   6.0  161.0      ...
# 14             52.173913   NL      WSN     E   3.0  161.0      ...
# 15             60.248447   AL      NYY     E   2.0  161.0      ...
# 16             60.493827   NL      NYM     E   2.0  162.0      ...
# 17             47.530864   AL      OAK     W   4.0  162.0      ...
# 18             46.296296   NL      PHI     E   5.0  162.0      ...
# 19             35.403727   NL      PIT     E   6.0  161.0      ...
# 20             51.234568   NL      SDP     W   3.0  162.0      ...
# 21             45.679012   AL      SEA     W   6.0  162.0      ...
# 22             38.271605   NL      SFG     W   6.0  162.0      ...
# 23             62.345679   NL      STL     E   1.0  162.0      ...
# 24             38.509317   AL      TEX     W   7.0  161.0      ...
# 25             61.490683   AL      TOR     E   1.0  161.0      ...
# 26             44.720497   NL      ATL     W   6.0  161.0      ...
# 27             45.061728   AL      BAL     E   7.0  162.0      ...
# 28             59.006211   AL      BOS     E   1.0  161.0      ...
# 29             56.790123   AL      ANA     W   1.0  162.0      ...
# ...                  ...  ...      ...   ...   ...    ...      ...
# 2747           45.774648   NL      STL  None   5.0  142.0      ...
# 2748           64.516129   NA      BNA  None   3.0   31.0      ...
# 2749           67.857143   NA      CNA  None   2.0   28.0      ...
# 2750           34.482759   NA      CFC  None   8.0   29.0      ...
# 2751           36.842105   NA      KEK  None   7.0   19.0      ...
# 2752           48.484848   NA      NNA  None   5.0   33.0      ...
# 2753           75.000000   NA      PNA  None   1.0   28.0      ...
# 2754           16.000000   NA      ROK  None   9.0   25.0      ...
# 2755           44.827586   NA      TRO  None   6.0   29.0      ...
# 2756           46.875000   NA      OLY  None   4.0   32.0      ...
# 2757           55.714286   NL      ATL  None   4.0   70.0      ...
# 2758           78.787879   NL      CHC  None   1.0   66.0      ...
# 2759           13.846154   NL      CNR  None   8.0   65.0      ...
# 2760           68.115942   NL      HAR  None   2.0   69.0      ...
# 2761           43.478261   NL      LGR  None   5.0   69.0      ...
# 2762           36.842105   NL      NYU  None   6.0   57.0      ...
# 2763           23.333333   NL      ATH  None   7.0   60.0      ...
# 2764           70.312500   NL      SBS  None   3.0   64.0      ...
# 2765           68.852459   NL      ATL  None   1.0   61.0      ...
# 2766           43.333333   NL      CHC  None   5.0   60.0      ...
# 2767           25.862069   NL      CNR  None   6.0   58.0      ...
# 2768           51.666667   NL      HAR  None   3.0   60.0      ...
# 2769           57.377049   NL      LGR  None   2.0   61.0      ...
# 2770           46.666667   NL      SBS  None   4.0   60.0      ...
# 2771           68.333333   NL      ATL  None   1.0   60.0      ...
# 2772           49.180328   NL      CHC  None   4.0   61.0      ...
# 2773           60.655738   NL      CNR  None   2.0   61.0      ...
# 2774           38.095238   NL      IBL  None   5.0   63.0      ...
# 2775           24.590164   NL      MLG  None   6.0   61.0      ...
# 2776           53.225806   NL      PRO  None   3.0   62.0      ...
#
#         FP                       name                               park  \
# 0     0.97             Atlanta Braves      Atlanta-Fulton County Stadium
# 1     0.98          Baltimore Orioles                   Memorial Stadium
# 2     0.97             Boston Red Sox                     Fenway Park II
# 3     0.98          California Angels                    Anaheim Stadium
# 4     0.98          Chicago White Sox                      Comiskey Park
# 5     0.97               Chicago Cubs                      Wrigley Field
# 6     0.98            Cincinnati Reds                 Riverfront Stadium
# 7     0.97          Cleveland Indians                  Cleveland Stadium
# 8     0.97             Detroit Tigers                      Tiger Stadium
# 9     0.97             Houston Astros                          Astrodome
# 10    0.98         Kansas City Royals                     Royals Stadium
# 11    0.97        Los Angeles Dodgers                     Dodger Stadium
# 12    0.98            Minnesota Twins        Hubert H Humphrey Metrodome
# 13    0.97          Milwaukee Brewers                     County Stadium
# 14    0.98             Montreal Expos                    Stade Olympique
# 15    0.97           New York Yankees                  Yankee Stadium II
# 16    0.98              New York Mets                       Shea Stadium
# 17    0.97          Oakland Athletics                   Oakland Coliseum
# 18    0.97      Philadelphia Phillies                   Veterans Stadium
# 19    0.97         Pittsburgh Pirates               Three Rivers Stadium
# 20    0.98           San Diego Padres                Jack Murphy Stadium
# 21    0.98           Seattle Mariners                           Kingdome
# 22    0.97       San Francisco Giants                   Candlestick Park
# 23    0.98        St. Louis Cardinals                   Busch Stadium II
# 24    0.98              Texas Rangers                  Arlington Stadium
# 25    0.98          Toronto Blue Jays                 Exhibition Stadium
# 26    0.97             Atlanta Braves      Atlanta-Fulton County Stadium
# 27    0.97          Baltimore Orioles                   Memorial Stadium
# 28    0.97             Boston Red Sox                     Fenway Park II
# 29    0.98          California Angels                    Anaheim Stadium
# ...    ...                        ...                                ...
# 2747  0.94        St. Louis Cardinals                      Robison Field
# 2748  0.83       Boston Red Stockings                South End Grounds I
# 2749  0.82    Chicago White Stockings            Union Base-Ball Grounds
# 2750  0.81     Cleveland Forest Citys       National Association Grounds
# 2751  0.80       Fort Wayne Kekiongas                     Hamilton Field
# 2752  0.83           New York Mutuals           Union Grounds (Brooklyn)
# 2753  0.84     Philadelphia Athletics           Jefferson Street Grounds
# 2754  0.82      Rockford Forest Citys  Agricultural Society Fair Grounds
# 2755  0.84             Troy Haymakers                 Haymakers' Grounds
# 2756  0.85        Washington Olympics                   Olympics Grounds
# 2757  0.86            Boston Red Caps                South End Grounds I
# 2758  0.89    Chicago White Stockings                23rd Street Grounds
# 2759  0.84            Cincinnati Reds                     Avenue Grounds
# 2760  0.88        Hartford Dark Blues         Hartford Ball Club Grounds
# 2761  0.87           Louisville Grays           Louisville Baseball Park
# 2762  0.82           New York Mutuals           Union Grounds (Brooklyn)
# 2763  0.83     Philadelphia Athletics           Jefferson Street Grounds
# 2764  0.90  St. Louis Brown Stockings                 Sportsman's Park I
# 2765  0.88            Boston Red Caps                South End Grounds I
# 2766  0.88    Chicago White Stockings                23rd Street Grounds
# 2767  0.85            Cincinnati Reds                     Avenue Grounds
# 2768  0.88        Hartford Dark Blues           Union Grounds (Brooklyn)
# 2769  0.90           Louisville Grays           Louisville Baseball Park
# 2770  0.89  St. Louis Brown Stockings                 Sportsman's Park I
# 2771  0.91            Boston Red Caps                South End Grounds I
# 2772  0.89    Chicago White Stockings                  Lake Front Park I
# 2773  0.90            Cincinnati Reds                     Avenue Grounds
# 2774  0.89         Indianapolis Blues                  South Street Park
# 2775  0.86            Milwaukee Grays                    Eclipse Park II
# 2776  0.89           Providence Grays              Messer Street Grounds
#
#      attendance    BPF    PPF teamIDBR  teamIDlahman45  teamIDretro  \
# 0     1350137.0  105.0  106.0      ATL             ATL          ATL
# 1     2132387.0   97.0   97.0      BAL             BAL          BAL
# 2     1786633.0  104.0  104.0      BOS             BOS          BOS
# 3     2567427.0  100.0  100.0      CAL             CAL          CAL
# 4     1669888.0  104.0  104.0      CHW             CHA          CHA
# 5     2161534.0  110.0  110.0      CHC             CHN          CHN
# 6     1834619.0  104.0  105.0      CIN             CIN          CIN
# 7      655181.0   99.0  100.0      CLE             CLE          CLE
# 8     2286609.0  100.0   98.0      DET             DET          DET
# 9     1184314.0   97.0   96.0      HOU             HOU          HOU
# 10    2162717.0  100.0  100.0      KCR             KCA          KCA
# 11    3264593.0   97.0   96.0      LAD             LAN          LAN
# 12    1651814.0  105.0  105.0      MIN             MIN          MIN
# 13    1360265.0  100.0  101.0      MIL             MIL          MIL
# 14    1502494.0   95.0   95.0      MON             MON          MON
# 15    2214587.0   98.0   97.0      NYY             NYA          NYA
# 16    2761601.0   99.0   97.0      NYM             NYN          NYN
# 17    1334599.0   92.0   92.0      OAK             OAK          OAK
# 18    1830350.0  103.0  103.0      PHI             PHI          PHI
# 19     735900.0   99.0  100.0      PIT             PIT          PIT
# 20    2210352.0   99.0   99.0      SDP             SDN          SDN
# 21    1128696.0  100.0  101.0      SEA             SEA          SEA
# 22     818697.0   95.0   96.0      SFG             SFN          SFN
# 23    2637563.0  100.0   99.0      STL             SLN          SLN
# 24    1112497.0  101.0  102.0      TEX             TEX          TEX
# 25    2468925.0  104.0  103.0      TOR             TOR          TOR
# 26    1387181.0  105.0  106.0      ATL             ATL          ATL
# 27    1973176.0   98.0   99.0      BAL             BAL          BAL
# 28    2147641.0  101.0  100.0      BOS             BOS          BOS
# 29    2655872.0   99.0   99.0      CAL             CAL          CAL
# ...         ...    ...    ...      ...             ...          ...
# 2747   270000.0   99.0   98.0      STL             SLN          SLN
# 2748        NaN  103.0   98.0      BOS             BS1          BS1
# 2749        NaN  104.0  102.0      CHI             CH1          CH1
# 2750        NaN   96.0  100.0      CLE             CL1          CL1
# 2751        NaN  101.0  107.0      KEK             FW1          FW1
# 2752        NaN   90.0   88.0      NYU             NY2          NY2
# 2753        NaN  102.0   98.0      ATH             PH1          PH1
# 2754        NaN   97.0   99.0      ROK             RC1          RC1
# 2755        NaN  101.0  100.0      TRO             TRO          TRO
# 2756        NaN   94.0   98.0      OLY             WS3          WS3
# 2757        NaN  102.0   98.0      BSN             BSN          BSN
# 2758        NaN  112.0  106.0      CHC             CHN          CHN
# 2759        NaN   86.0   95.0      CIN             CN1          CN1
# 2760        NaN  110.0  106.0      HAR             HAR          HAR
# 2761        NaN  117.0  117.0      LOU             LS1          LS1
# 2762        NaN   96.0  100.0      NYU             NY3          NY3
# 2763        NaN  104.0  104.0      ATH             PHN          PHN
# 2764        NaN   93.0   92.0      STL             SL3          SL3
# 2765        NaN  104.0  100.0      BSN             BSN          BSN
# 2766        NaN  112.0  106.0      CHC             CHN          CHN
# 2767        NaN   89.0   94.0      CIN             CN1          CN1
# 2768        NaN   90.0   87.0      HAR             HAR          HAR
# 2769        NaN  117.0  117.0      LOU             LS1          LS1
# 2770        NaN   95.0   93.0      STL             SL3          SL3
# 2771        NaN  108.0  102.0      BSN             BSN          BSN
# 2772        NaN  106.0  105.0      CHC             CHN          CHN
# 2773        NaN   91.0   92.0      CIN             CN1          CN1
# 2774        NaN   87.0   89.0      IND             IN1          IN1
# 2775        NaN  106.0  113.0      MLG             ML2          ML2
# 2776        NaN  100.0   96.0      PRO             PRO          PRO
#
#         salary_mean
# 0     476299.447273
# 1     476299.447273
# 2     476299.447273
# 3     476299.447273
# 4     476299.447273
# 5     476299.447273
# 6     476299.447273
# 7     476299.447273
# 8     476299.447273
# 9     476299.447273
# 10    476299.447273
# 11    476299.447273
# 12    476299.447273
# 13    476299.447273
# 14    476299.447273
# 15    476299.447273
# 16    476299.447273
# 17    476299.447273
# 18    476299.447273
# 19    476299.447273
# 20    476299.447273
# 21    476299.447273
# 22    476299.447273
# 23    476299.447273
# 24    476299.447273
# 25    476299.447273
# 26    417147.043360
# 27    417147.043360
# 28    417147.043360
# 29    417147.043360
# ...             ...
# 2747            NaN
# 2748            NaN
# 2749            NaN
# 2750            NaN
# 2751            NaN
# 2752            NaN
# 2753            NaN
# 2754            NaN
# 2755            NaN
# 2756            NaN
# 2757            NaN
# 2758            NaN
# 2759            NaN
# 2760            NaN
# 2761            NaN
# 2762            NaN
# 2763            NaN
# 2764            NaN
# 2765            NaN
# 2766            NaN
# 2767            NaN
# 2768            NaN
# 2769            NaN
# 2770            NaN
# 2771            NaN
# 2772            NaN
# 2773            NaN
# 2774            NaN
# 2775            NaN
# 2776            NaN
#
# [2777 rows x 52 columns]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

## Part 2
## Problem 2
result.sort_values("yearID", ascending=True)
plt.plot(result['yearID'], result['total_payroll_by_thousand'], '*')

# %%
## Problem 3
result.sort_values("salary_mean", ascending=True)
plt.plot(result['yearID'],result['salary_mean'],'*')

# %%
## Problem 4
new_query = "SELECT  teamID,yearID, sum(salary)/count(salary) as payroll_mean FROM Salaries GROUP BY teamID,yearID"
new_query2 = "SELECT  teamID,yearID, W*100/G as winning_percentage FROM Teams GROUP BY teamID,yearID"
query1 = pandas.read_sql(new_query, conn)
query2 = pandas.read_sql(new_query2,conn)

group_table = pandas.merge(query1, query2, how='outer', on=['yearID','teamID'])

bins = [1989,1994,1999,2004,2009,2015]
group_names = ['1990-1994','1995-1999','2000-2004','2005-2009','2010-2015']
categories = pandas.cut(group_table['yearID'],bins,labels=group_names)
group_table['categories'] = pandas.cut(group_table['yearID'], bins, labels=group_names)

grouped = group_table.groupby('categories')

group1 = grouped.get_group('1990-1994')
group2 = grouped.get_group('1995-1999')
group3 = grouped.get_group('2000-2004')
group4 = grouped.get_group('2005-2009')
group5 = grouped.get_group('2010-2015')

# %%
## Plot for 1990-1994
plt.plot(group1['winning_percentage'],group1['payroll_mean'],'*')

# %%
## Plot for 1995-1999
plt.plot(group2['winning_percentage'],group2['payroll_mean'],'*')

# %%
## Plot for 2000-2004
plt.plot(group3['winning_percentage'],group3['payroll_mean'],'*')

# %%
## Plot for 2005-2009
plt.plot(group4['winning_percentage'],group4['payroll_mean'],'*')

# %%
## Plot for 2010-2015
plt.plot(group5['winning_percentage'],group5['payroll_mean'],'*')

# %%
## Problem 5
import statistics
query1
curr = 1985
payroll_lst = []
payroll_avg = {}
payroll_std = {}

for index, row in query1.iterrows():
    if curr == row['yearID']:
        payroll_lst.append(row['payroll_mean'])
    else:
        avg = statistics.mean(payroll_lst)
        std = statistics.stdev(payroll_lst)
        payroll_avg[curr] = avg
        payroll_std[curr] = std
        curr = row['yearID']
        payroll_lst= [row['payroll_mean']]
        
payroll_std[curr] = statistics.stdev(payroll_lst)
payroll_avg[curr] = statistics.mean(payroll_lst)

stand_lst = []

for index, row in query1.iterrows():
    curr = row['yearID']
    payroll = row['payroll_mean']
    stand_lst.append((payroll - payroll_avg[curr]) / payroll_std[curr])
    
query1['Standardized_Payroll'] = stand_lst

query1
# Out:
#     teamID  yearID  payroll_mean  Standardized_Payroll
# 0      ATL    1985  6.730455e+05              1.946823
# 1      BAL    1985  5.254869e+05              0.500248
# 2      BOS    1985  4.359024e+05             -0.377984
# 3      CAL    1985  5.152819e+05              0.400205
# 4      CHA    1985  4.688656e+05             -0.054832
# 5      CHN    1985  5.774053e+05              1.009225
# 6      CIN    1985  3.799962e+05             -0.926054
# 7      CLE    1985  3.275833e+05             -1.439879
# 8      DET    1985  5.174072e+05              0.421039
# 9      HOU    1985  4.996525e+05              0.246984
# 10     KCA    1985  4.236900e+05             -0.497707
# 11     LAN    1985  4.768660e+05              0.023598
# 12     MIN    1985  3.034116e+05             -1.676843
# 13     ML4    1985  5.939004e+05              1.170933
# 14     MON    1985  4.735083e+05             -0.009318
# 15     NYA    1985  7.119102e+05              2.327829
# 16     NYN    1985  5.159410e+05              0.406667
# 17     OAK    1985  4.313622e+05             -0.422493
# 18     PHI    1985  5.328929e+05              0.572853
# 19     PIT    1985  4.856579e+05              0.109789
# 20     SDN    1985  5.016629e+05              0.266692
# 21     SEA    1985  2.562778e+05             -2.138915
# 22     SFN    1985  4.110857e+05             -0.621272
# 23     SLN    1985  4.726833e+05             -0.017406
# 24     TEX    1985  3.838250e+05             -0.888519
# 25     TOR    1985  4.406275e+05             -0.331662
# 26     ATL    1986  5.897512e+05              1.633549
# 27     BAL    1986  4.483192e+05              0.296232
# 28     BOS    1986  4.966289e+05              0.753027
# 29     CAL    1986  4.974917e+05              0.761184
# ..     ...     ...           ...                   ...
# 830    BAL    2014  3.693429e+06             -0.273483
# 831    BOS    2014  4.484514e+06             -0.037340
# 832    CHA    2014  3.409604e+06             -0.358206
# 833    CHN    2014  2.426759e+06             -0.651589
# 834    CIN    2014  3.864911e+06             -0.222295
# 835    CLE    2014  3.159688e+06             -0.432807
# 836    COL    2014  3.180117e+06             -0.426709
# 837    DET    2014  6.645891e+06              0.607841
# 838    HOU    2014  1.755815e+06             -0.851869
# 839    KCA    2014  2.983763e+06             -0.485321
# 840    LAA    2014  4.518083e+06             -0.027320
# 841    LAN    2014  6.781706e+06              0.648382
# 842    MIA    2014  1.549515e+06             -0.913451
# 843    MIL    2014  3.748778e+06             -0.256961
# 844    MIN    2014  3.102315e+06             -0.449933
# 845    NYA    2014  8.230996e+06              1.081002
# 846    NYM    2014  2.283625e+06             -0.694316
# 847    NYN    2014  1.025000e+07              1.683684
# 848    OAK    2014  2.784938e+06             -0.544671
# 849    PHI    2014  5.654530e+06              0.311915
# 850    PIT    2014  2.756357e+06             -0.553203
# 851    SDN    2014  2.703061e+06             -0.569112
# 852    SEA    2014  3.701244e+06             -0.271150
# 853    SFG    2014  5.315191e+06              0.210621
# 854    SFN    2014  2.000000e+07              4.594103
# 855    SLN    2014  4.310464e+06             -0.089295
# 856    TBA    2014  2.907564e+06             -0.508067
# 857    TEX    2014  4.677294e+06              0.020206
# 858    TOR    2014  4.396804e+06             -0.063522
# 859    WAS    2014  4.399456e+06             -0.062730
#
# [860 rows x 4 columns]

# %%
## Problem 6

group_table = pandas.merge(query1, query2, how='outer', on=['yearID','teamID'])

bins = [1989,1994,1999,2004,2009,2015]
group_names = ['1990-1994','1995-1999','2000-2004','2005-2009','2010-2015']
categories = pandas.cut(group_table['yearID'],bins,labels=group_names)
group_table['categories'] = pandas.cut(group_table['yearID'], bins, labels=group_names)

grouped = group_table.groupby('categories')

group1 = grouped.get_group('1990-1994')
group2 = grouped.get_group('1995-1999')
group3 = grouped.get_group('2000-2004')
group4 = grouped.get_group('2005-2009')
group5 = grouped.get_group('2010-2015')

# %%
## Plot for 1990-1994
plt.plot(group1['winning_percentage'],group1['Standardized_Payroll'],'*')

# %%
## Plot for 1995-1999
plt.plot(group2['winning_percentage'],group2['Standardized_Payroll'],'*')

# %%
## Plot for 2000-2004
plt.plot(group3['winning_percentage'],group3['Standardized_Payroll'],'*')

# %%
## Plot for 2005-2009
plt.plot(group4['winning_percentage'],group4['Standardized_Payroll'],'*')

# %%
## Plot for 2010-2015
plt.plot(group5['winning_percentage'],group5['Standardized_Payroll'],'*')
