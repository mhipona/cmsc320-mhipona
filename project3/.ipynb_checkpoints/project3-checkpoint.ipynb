# %%
import pandas as pd
data = pd.read_csv("gap.tsv", sep='\t')
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
## Exercise 1
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline
plt.plot(data['year'], data['lifeExp'], "^")
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import ggplot
from ggplot import *
ggplot(aes(x='year', y='lifeExp'), data=data) +\
    geom_violin() +\
    labs(title="Life expectancy over time",
         x = "year",
         y = "life expectancy")
# Out:
# <ggplot: (8753929435940)>

# %%
## Question 1

# %%
## Question 2
# During the the earlier years such as years 1952-1982, it is skewed towards the bottom. This means the life expectancy is 
# lower during these years in most countries.

## Question 3
## Question 4
## Question 5

# %%
## Exercise 2
import numpy as np
from sklearn import linear_model
reg = linear_model.LinearRegression()
X = [[x] for x in data['year'].values]
Y = [[y] for y in data['lifeExp'].values]
regfit = reg.fit(X, Y)

# %%
## Question 6
## Question 7

# %%
##Exercise 3
pred_lifeExps = []
for x in data['year'].values:
    #print(regfit.predict(x)[0][0])
    pred_lifeExps.append(regfit.predict(x)[0][0])
data['pred_lifeExp'] = pd.Series(pred_lifeExps, index = data.index)
data['residual'] = data['lifeExp'] - data['pred_lifeExp']
ggplot(aes(x='year', y='residual'), data=data) +\
    geom_violin() +\
    labs(title="Life expectancy over time",
         x = "year",
         y = "life expectancy")
# Out:
# <ggplot: (8753929146888)>

# %%
## Question 8

# %%
## Exercise 4

ggplot(aes(x='continent', y='residual'), data=data) +\
  geom_boxplot() +\
theme_bw()
# Out:
# <ggplot: (8753929326137)>

# %%
## Question 9

# %%
## Exercise 5stat_smooth(method = "lm", se=True, span=0.2) +\

ggplot(aes(x='year', y='lifeExp', color='continent'), data=data) +\
    geom_line() +\
    stat_smooth(method = "lm", se=True, span=0.2) +\
    geom_point(size=20) +\
    theme_bw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-4ab8249e5936> in <module>()
#       1 ## Exercise 5stat_smooth(method = "lm", se=True, span=0.2) +\
#       2
# ----> 3 ggplot(aes(x='year', y='lifeExp', color='continent'), data=data) +    geom_line() +    geom_smooth(method = "lm", se=True, span=0.2) +    geom_point(size=20) +    theme_bw()
#
# NameError: name 'geom_smooth' is not defined

# %%
## Question 10
